# %%
# !pip install sentencepiece sacrebleu
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (0.1.96)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.7/dist-packages (2.0.0)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.4.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.19.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2.3.2)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/MyDrive/cs224n/a4
# Out:
# /content/gdrive/MyDrive/cs224n/a4

# %%
# !python sanity_check.py 1d
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Running Sanity Check for Question 1d: Encode
# --------------------------------------------------------------------------------
# enc_hiddens Sanity Checks Passed!
# dec_init_state[0] Sanity Checks Passed!
# dec_init_state[1] Sanity Checks Passed!
# --------------------------------------------------------------------------------
# All Sanity Checks Passed for Question 1d: Encode!
# --------------------------------------------------------------------------------

# %%
# !python sanity_check.py 1e
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# --------------------------------------------------------------------------------
# Running Sanity Check for Question 1e: Decode
# --------------------------------------------------------------------------------
# torch.Size([23, 5, 3])
# combined_outputs Sanity Checks Passed!
# --------------------------------------------------------------------------------
# All Sanity Checks Passed for Question 1e: Decode!
# --------------------------------------------------------------------------------

# %%
# !python sanity_check.py 1f
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# --------------------------------------------------------------------------------
# Running Sanity Check for Question 1f: Step
# --------------------------------------------------------------------------------
# dec_state[0] Sanity Checks Passed!
# dec_state[1] Sanity Checks Passed!
# combined_output  Sanity Checks Passed!
# e_t Sanity Checks Passed!
# --------------------------------------------------------------------------------
# All Sanity Checks Passed for Question 1f: Step!
# --------------------------------------------------------------------------------

# %%
# !sh run.sh vocab
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# read in source sentences: ./chr_en_data/train.chr
# read in target sentences: ./chr_en_data/train.en
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: ./chr_en_data/train.chr
#   input_format:
#   model_prefix: src
#   model_type: UNIGRAM
#   vocab_size: 21000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: ./chr_en_data/train.chr
# trainer_interface.cc(385) LOG(INFO) Loaded all 14855 sentences
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=985616
# trainer_interface.cc(477) LOG(INFO) Done: 99.9511% characters are covered.
# trainer_interface.cc(487) LOG(INFO) Alphabet size=115
# trainer_interface.cc(488) LOG(INFO) Final character coverage=0.999511
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 14855 sentences.
# unigram_model_trainer.cc(139) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(143) LOG(INFO) Extracting frequent sub strings...
# unigram_model_trainer.cc(194) LOG(INFO) Initialized 68377 seed sentencepieces
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 14855
# trainer_interface.cc(537) LOG(INFO) Done! 51286
# unigram_model_trainer.cc(489) LOG(INFO) Using 51286 sentences for EM training
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=30248 obj=13.1327 num_tokens=111575 num_tokens/piece=3.68867
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=27152 obj=11.2574 num_tokens=111787 num_tokens/piece=4.11708
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=23072 obj=11.2492 num_tokens=114636 num_tokens/piece=4.96862
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=22929 obj=11.2127 num_tokens=114710 num_tokens/piece=5.00283
# trainer_interface.cc(615) LOG(INFO) Saving model: src.model
# trainer_interface.cc(626) LOG(INFO) Saving vocabs: src.vocab
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: ./chr_en_data/train.en
#   input_format:
#   model_prefix: tgt
#   model_type: UNIGRAM
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: ./chr_en_data/train.en
# trainer_interface.cc(385) LOG(INFO) Loaded all 14855 sentences
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=1574206
# trainer_interface.cc(477) LOG(INFO) Done: 99.9535% characters are covered.
# trainer_interface.cc(487) LOG(INFO) Alphabet size=61
# trainer_interface.cc(488) LOG(INFO) Final character coverage=0.999535
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 14855 sentences.
# unigram_model_trainer.cc(139) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(143) LOG(INFO) Extracting frequent sub strings...
# unigram_model_trainer.cc(194) LOG(INFO) Initialized 34247 seed sentencepieces
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 14855
# trainer_interface.cc(537) LOG(INFO) Done! 23391
# unigram_model_trainer.cc(489) LOG(INFO) Using 23391 sentences for EM training
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=12331 obj=9.86555 num_tokens=46325 num_tokens/piece=3.75679
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=10251 obj=7.84065 num_tokens=46467 num_tokens/piece=4.53292
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=8796 obj=7.7791 num_tokens=47496 num_tokens/piece=5.39973
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=8785 obj=7.76306 num_tokens=47512 num_tokens/piece=5.40831
# trainer_interface.cc(615) LOG(INFO) Saving model: tgt.model
# trainer_interface.cc(626) LOG(INFO) Saving vocabs: tgt.vocab
# initialize source vocabulary ..
# initialize target vocabulary ..
# generated vocabulary, source 21000 words, target 8000 words
# vocabulary saved to vocab.json

# %%
# !sh run.sh train_local
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cpu
# begin Maximum Likelihood training
# epoch 1, iter 10, avg. loss 205.79, avg. ppl 3012.31 cum. examples 320, speed 86.08 words/sec, time elapsed 95.50 sec
# Traceback (most recent call last):
#   File "run.py", line 360, in <module>
#     main()
#   File "run.py", line 352, in main
#     train(args)
#   File "run.py", line 185, in train
#     loss.backward()
#   File "/usr/local/lib/python3.7/dist-packages/torch/_tensor.py", line 255, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py", line 149, in backward
#     allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
# KeyboardInterrupt
# ^C

# %%
# ppl = perplexity
# !sh run.sh train
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 10, avg. loss 207.12, avg. ppl 3172.12 cum. examples 320, speed 5667.40 words/sec, time elapsed 1.45 sec
# epoch 1, iter 20, avg. loss 177.06, avg. ppl 743.35 cum. examples 640, speed 5592.64 words/sec, time elapsed 2.98 sec
# epoch 1, iter 30, avg. loss 164.64, avg. ppl 537.08 cum. examples 960, speed 5323.49 words/sec, time elapsed 4.56 sec
# epoch 1, iter 40, avg. loss 170.57, avg. ppl 474.92 cum. examples 1280, speed 5263.52 words/sec, time elapsed 6.24 sec
# epoch 1, iter 50, avg. loss 161.77, avg. ppl 366.53 cum. examples 1600, speed 5830.25 words/sec, time elapsed 7.74 sec
# epoch 1, iter 60, avg. loss 153.55, avg. ppl 345.13 cum. examples 1920, speed 5801.53 words/sec, time elapsed 9.19 sec
# epoch 1, iter 70, avg. loss 152.71, avg. ppl 293.03 cum. examples 2240, speed 5362.01 words/sec, time elapsed 10.80 sec
# epoch 1, iter 80, avg. loss 150.85, avg. ppl 298.20 cum. examples 2560, speed 5310.33 words/sec, time elapsed 12.39 sec
# epoch 1, iter 90, avg. loss 143.59, avg. ppl 261.61 cum. examples 2880, speed 5127.02 words/sec, time elapsed 14.00 sec
# epoch 1, iter 100, avg. loss 142.24, avg. ppl 218.04 cum. examples 3200, speed 5655.71 words/sec, time elapsed 15.50 sec
# epoch 1, iter 110, avg. loss 139.32, avg. ppl 220.26 cum. examples 3520, speed 5492.65 words/sec, time elapsed 17.00 sec
# epoch 1, iter 120, avg. loss 129.23, avg. ppl 191.35 cum. examples 3840, speed 5782.93 words/sec, time elapsed 18.36 sec
# epoch 1, iter 130, avg. loss 136.37, avg. ppl 181.52 cum. examples 4160, speed 5905.32 words/sec, time elapsed 19.78 sec
# epoch 1, iter 140, avg. loss 132.42, avg. ppl 177.74 cum. examples 4480, speed 5573.77 words/sec, time elapsed 21.25 sec
# epoch 1, iter 150, avg. loss 134.44, avg. ppl 170.28 cum. examples 4800, speed 6046.46 words/sec, time elapsed 22.64 sec
# epoch 1, iter 160, avg. loss 129.35, avg. ppl 156.92 cum. examples 5120, speed 5602.19 words/sec, time elapsed 24.10 sec
# epoch 1, iter 170, avg. loss 132.12, avg. ppl 162.22 cum. examples 5440, speed 4979.09 words/sec, time elapsed 25.77 sec
# epoch 1, iter 180, avg. loss 137.40, avg. ppl 147.98 cum. examples 5760, speed 5704.96 words/sec, time elapsed 27.31 sec
# epoch 1, iter 190, avg. loss 136.05, avg. ppl 160.40 cum. examples 6080, speed 5030.40 words/sec, time elapsed 29.01 sec
# epoch 1, iter 200, avg. loss 127.81, avg. ppl 136.35 cum. examples 6400, speed 4878.21 words/sec, time elapsed 30.72 sec
# epoch 1, iter 200, cum. loss 147.93, cum. ppl 277.81 cum. examples 6400
# begin validation ...
# validation: iter 200, dev. ppl 144.816495
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 1, iter 210, avg. loss 122.85, avg. ppl 147.42 cum. examples 320, speed 1214.93 words/sec, time elapsed 37.20 sec
# epoch 1, iter 220, avg. loss 132.91, avg. ppl 136.28 cum. examples 640, speed 5691.56 words/sec, time elapsed 38.72 sec
# epoch 1, iter 230, avg. loss 122.31, avg. ppl 116.49 cum. examples 960, speed 5866.07 words/sec, time elapsed 40.12 sec
# epoch 1, iter 240, avg. loss 126.47, avg. ppl 114.93 cum. examples 1280, speed 5454.62 words/sec, time elapsed 41.69 sec
# epoch 1, iter 250, avg. loss 127.09, avg. ppl 115.38 cum. examples 1600, speed 5736.05 words/sec, time elapsed 43.18 sec
# epoch 1, iter 260, avg. loss 126.08, avg. ppl 100.36 cum. examples 1920, speed 5777.71 words/sec, time elapsed 44.69 sec
# epoch 1, iter 270, avg. loss 114.60, avg. ppl 102.89 cum. examples 2240, speed 5762.94 words/sec, time elapsed 46.07 sec
# epoch 1, iter 280, avg. loss 121.33, avg. ppl 106.16 cum. examples 2560, speed 5504.84 words/sec, time elapsed 47.58 sec
# epoch 1, iter 290, avg. loss 129.97, avg. ppl 124.85 cum. examples 2880, speed 5074.94 words/sec, time elapsed 49.28 sec
# epoch 1, iter 300, avg. loss 121.54, avg. ppl 103.95 cum. examples 3200, speed 5572.71 words/sec, time elapsed 50.78 sec
# epoch 1, iter 310, avg. loss 121.36, avg. ppl 95.98 cum. examples 3520, speed 5546.80 words/sec, time elapsed 52.31 sec
# epoch 1, iter 320, avg. loss 118.74, avg. ppl 93.34 cum. examples 3840, speed 5129.36 words/sec, time elapsed 53.95 sec
# epoch 1, iter 330, avg. loss 121.82, avg. ppl 99.72 cum. examples 4160, speed 5932.43 words/sec, time elapsed 55.38 sec
# epoch 1, iter 340, avg. loss 105.05, avg. ppl 85.34 cum. examples 4480, speed 5542.65 words/sec, time elapsed 56.74 sec
# epoch 1, iter 350, avg. loss 113.87, avg. ppl 90.00 cum. examples 4800, speed 6014.16 words/sec, time elapsed 58.09 sec
# epoch 1, iter 360, avg. loss 113.58, avg. ppl 86.06 cum. examples 5120, speed 5130.52 words/sec, time elapsed 59.68 sec
# epoch 1, iter 370, avg. loss 113.67, avg. ppl 88.98 cum. examples 5440, speed 5454.55 words/sec, time elapsed 61.16 sec
# epoch 1, iter 380, avg. loss 114.54, avg. ppl 93.71 cum. examples 5760, speed 5430.93 words/sec, time elapsed 62.65 sec
# epoch 1, iter 390, avg. loss 117.14, avg. ppl 80.38 cum. examples 6080, speed 5226.31 words/sec, time elapsed 64.28 sec
# epoch 1, iter 400, avg. loss 119.02, avg. ppl 82.68 cum. examples 6400, speed 5388.03 words/sec, time elapsed 65.88 sec
# epoch 1, iter 400, cum. loss 120.20, cum. ppl 101.94 cum. examples 6400
# begin validation ...
# validation: iter 400, dev. ppl 88.827232
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 1, iter 410, avg. loss 109.57, avg. ppl 70.63 cum. examples 320, speed 1275.59 words/sec, time elapsed 72.34 sec
# epoch 1, iter 420, avg. loss 112.50, avg. ppl 69.08 cum. examples 640, speed 6074.80 words/sec, time elapsed 73.74 sec
# epoch 1, iter 430, avg. loss 115.01, avg. ppl 86.38 cum. examples 960, speed 5796.91 words/sec, time elapsed 75.16 sec
# epoch 1, iter 440, avg. loss 112.62, avg. ppl 75.20 cum. examples 1280, speed 5251.03 words/sec, time elapsed 76.75 sec
# epoch 1, iter 450, avg. loss 107.44, avg. ppl 70.95 cum. examples 1600, speed 4957.72 words/sec, time elapsed 78.38 sec
# epoch 1, iter 460, avg. loss 114.89, avg. ppl 80.50 cum. examples 1920, speed 5047.45 words/sec, time elapsed 80.04 sec
# epoch 2, iter 470, avg. loss 110.64, avg. ppl 61.66 cum. examples 2215, speed 5127.05 words/sec, time elapsed 81.59 sec
# epoch 2, iter 480, avg. loss 104.42, avg. ppl 51.51 cum. examples 2535, speed 5531.17 words/sec, time elapsed 83.12 sec
# epoch 2, iter 490, avg. loss 103.13, avg. ppl 54.34 cum. examples 2855, speed 5223.23 words/sec, time elapsed 84.70 sec
# epoch 2, iter 500, avg. loss 99.85, avg. ppl 52.42 cum. examples 3175, speed 5014.75 words/sec, time elapsed 86.31 sec
# epoch 2, iter 510, avg. loss 101.78, avg. ppl 50.54 cum. examples 3495, speed 4960.88 words/sec, time elapsed 87.98 sec
# epoch 2, iter 520, avg. loss 99.46, avg. ppl 52.65 cum. examples 3815, speed 5414.69 words/sec, time elapsed 89.47 sec
# epoch 2, iter 530, avg. loss 104.01, avg. ppl 47.90 cum. examples 4135, speed 5153.87 words/sec, time elapsed 91.13 sec
# epoch 2, iter 540, avg. loss 103.00, avg. ppl 50.41 cum. examples 4455, speed 5179.21 words/sec, time elapsed 92.76 sec
# epoch 2, iter 550, avg. loss 100.81, avg. ppl 46.04 cum. examples 4775, speed 5226.30 words/sec, time elapsed 94.37 sec
# epoch 2, iter 560, avg. loss 103.91, avg. ppl 49.58 cum. examples 5095, speed 5745.82 words/sec, time elapsed 95.85 sec
# epoch 2, iter 570, avg. loss 104.21, avg. ppl 54.67 cum. examples 5415, speed 5114.46 words/sec, time elapsed 97.48 sec
# epoch 2, iter 580, avg. loss 100.40, avg. ppl 51.67 cum. examples 5735, speed 5489.69 words/sec, time elapsed 98.97 sec
# epoch 2, iter 590, avg. loss 105.71, avg. ppl 44.23 cum. examples 6055, speed 5453.11 words/sec, time elapsed 100.60 sec
# epoch 2, iter 600, avg. loss 104.72, avg. ppl 48.22 cum. examples 6375, speed 5739.70 words/sec, time elapsed 102.11 sec
# epoch 2, iter 600, cum. loss 105.89, cum. ppl 57.17 cum. examples 6375
# begin validation ...
# validation: iter 600, dev. ppl 67.290032
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 2, iter 610, avg. loss 104.35, avg. ppl 50.94 cum. examples 320, speed 1327.05 words/sec, time elapsed 108.51 sec
# epoch 2, iter 620, avg. loss 104.46, avg. ppl 45.49 cum. examples 640, speed 5839.31 words/sec, time elapsed 110.01 sec
# epoch 2, iter 630, avg. loss 91.61, avg. ppl 41.26 cum. examples 960, speed 5424.62 words/sec, time elapsed 111.46 sec
# epoch 2, iter 640, avg. loss 112.30, avg. ppl 53.48 cum. examples 1280, speed 5288.76 words/sec, time elapsed 113.17 sec
# epoch 2, iter 650, avg. loss 95.19, avg. ppl 46.55 cum. examples 1600, speed 5024.00 words/sec, time elapsed 114.75 sec
# epoch 2, iter 660, avg. loss 97.00, avg. ppl 44.79 cum. examples 1920, speed 4816.04 words/sec, time elapsed 116.44 sec
# epoch 2, iter 670, avg. loss 93.97, avg. ppl 44.33 cum. examples 2240, speed 5807.18 words/sec, time elapsed 117.81 sec
# epoch 2, iter 680, avg. loss 101.29, avg. ppl 46.48 cum. examples 2560, speed 5443.59 words/sec, time elapsed 119.36 sec
# epoch 2, iter 690, avg. loss 103.21, avg. ppl 48.33 cum. examples 2880, speed 5549.11 words/sec, time elapsed 120.90 sec
# epoch 2, iter 700, avg. loss 100.05, avg. ppl 40.44 cum. examples 3200, speed 5169.67 words/sec, time elapsed 122.57 sec
# epoch 2, iter 710, avg. loss 98.23, avg. ppl 42.18 cum. examples 3520, speed 5655.60 words/sec, time elapsed 124.06 sec
# epoch 2, iter 720, avg. loss 100.38, avg. ppl 45.36 cum. examples 3840, speed 5061.55 words/sec, time elapsed 125.72 sec
# epoch 2, iter 730, avg. loss 100.80, avg. ppl 46.27 cum. examples 4160, speed 5602.52 words/sec, time elapsed 127.22 sec
# epoch 2, iter 740, avg. loss 100.86, avg. ppl 44.00 cum. examples 4480, speed 5803.95 words/sec, time elapsed 128.69 sec
# epoch 2, iter 750, avg. loss 92.62, avg. ppl 36.82 cum. examples 4800, speed 5815.31 words/sec, time elapsed 130.10 sec
# epoch 2, iter 760, avg. loss 96.19, avg. ppl 39.45 cum. examples 5120, speed 5747.07 words/sec, time elapsed 131.56 sec
# epoch 2, iter 770, avg. loss 96.54, avg. ppl 40.93 cum. examples 5440, speed 5298.76 words/sec, time elapsed 133.13 sec
# epoch 2, iter 780, avg. loss 95.07, avg. ppl 38.50 cum. examples 5760, speed 5573.64 words/sec, time elapsed 134.63 sec
# epoch 2, iter 790, avg. loss 95.09, avg. ppl 40.90 cum. examples 6080, speed 5483.05 words/sec, time elapsed 136.12 sec
# epoch 2, iter 800, avg. loss 94.40, avg. ppl 40.01 cum. examples 6400, speed 5727.60 words/sec, time elapsed 137.55 sec
# epoch 2, iter 800, cum. loss 98.68, cum. ppl 43.69 cum. examples 6400
# begin validation ...
# validation: iter 800, dev. ppl 55.918184
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 2, iter 810, avg. loss 99.83, avg. ppl 42.34 cum. examples 320, speed 1215.08 words/sec, time elapsed 144.57 sec
# epoch 2, iter 820, avg. loss 97.55, avg. ppl 39.15 cum. examples 640, speed 5915.92 words/sec, time elapsed 146.01 sec
# epoch 2, iter 830, avg. loss 93.95, avg. ppl 40.88 cum. examples 960, speed 5873.35 words/sec, time elapsed 147.39 sec
# epoch 2, iter 840, avg. loss 96.69, avg. ppl 38.64 cum. examples 1280, speed 5624.55 words/sec, time elapsed 148.89 sec
# epoch 2, iter 850, avg. loss 92.83, avg. ppl 37.53 cum. examples 1600, speed 5060.74 words/sec, time elapsed 150.51 sec
# epoch 2, iter 860, avg. loss 93.59, avg. ppl 38.46 cum. examples 1920, speed 5449.79 words/sec, time elapsed 152.02 sec
# epoch 2, iter 870, avg. loss 95.20, avg. ppl 39.18 cum. examples 2240, speed 5170.31 words/sec, time elapsed 153.63 sec
# epoch 2, iter 880, avg. loss 91.40, avg. ppl 36.69 cum. examples 2560, speed 5579.92 words/sec, time elapsed 155.08 sec
# epoch 2, iter 890, avg. loss 92.29, avg. ppl 37.19 cum. examples 2880, speed 5215.04 words/sec, time elapsed 156.65 sec
# epoch 2, iter 900, avg. loss 88.77, avg. ppl 34.09 cum. examples 3200, speed 5478.57 words/sec, time elapsed 158.12 sec
# epoch 2, iter 910, avg. loss 95.13, avg. ppl 37.73 cum. examples 3520, speed 4894.22 words/sec, time elapsed 159.83 sec
# epoch 2, iter 920, avg. loss 97.06, avg. ppl 38.40 cum. examples 3840, speed 5943.85 words/sec, time elapsed 161.26 sec
# epoch 2, iter 930, avg. loss 92.47, avg. ppl 34.07 cum. examples 4135, speed 5444.92 words/sec, time elapsed 162.68 sec
# epoch 3, iter 940, avg. loss 82.40, avg. ppl 24.18 cum. examples 4455, speed 5486.94 words/sec, time elapsed 164.19 sec
# epoch 3, iter 950, avg. loss 84.47, avg. ppl 24.70 cum. examples 4775, speed 5775.24 words/sec, time elapsed 165.65 sec
# epoch 3, iter 960, avg. loss 83.57, avg. ppl 23.09 cum. examples 5095, speed 5573.52 words/sec, time elapsed 167.18 sec
# epoch 3, iter 970, avg. loss 79.32, avg. ppl 23.51 cum. examples 5415, speed 5787.05 words/sec, time elapsed 168.57 sec
# epoch 3, iter 980, avg. loss 86.12, avg. ppl 22.33 cum. examples 5735, speed 5636.10 words/sec, time elapsed 170.14 sec
# epoch 3, iter 990, avg. loss 82.84, avg. ppl 23.00 cum. examples 6055, speed 5545.25 words/sec, time elapsed 171.67 sec
# epoch 3, iter 1000, avg. loss 81.78, avg. ppl 23.23 cum. examples 6375, speed 6117.01 words/sec, time elapsed 173.03 sec
# epoch 3, iter 1000, cum. loss 90.35, cum. ppl 32.01 cum. examples 6375
# begin validation ...
# validation: iter 1000, dev. ppl 48.656144
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 3, iter 1010, avg. loss 81.13, avg. ppl 20.62 cum. examples 320, speed 1240.38 words/sec, time elapsed 179.94 sec
# epoch 3, iter 1020, avg. loss 85.25, avg. ppl 25.27 cum. examples 640, speed 4968.70 words/sec, time elapsed 181.64 sec
# epoch 3, iter 1030, avg. loss 76.81, avg. ppl 20.75 cum. examples 960, speed 5433.54 words/sec, time elapsed 183.13 sec
# epoch 3, iter 1040, avg. loss 81.36, avg. ppl 24.15 cum. examples 1280, speed 5498.61 words/sec, time elapsed 184.62 sec
# epoch 3, iter 1050, avg. loss 84.33, avg. ppl 24.70 cum. examples 1600, speed 5165.61 words/sec, time elapsed 186.25 sec
# epoch 3, iter 1060, avg. loss 80.96, avg. ppl 22.75 cum. examples 1920, speed 5706.93 words/sec, time elapsed 187.70 sec
# epoch 3, iter 1070, avg. loss 83.44, avg. ppl 21.33 cum. examples 2240, speed 5644.87 words/sec, time elapsed 189.25 sec
# epoch 3, iter 1080, avg. loss 79.81, avg. ppl 21.52 cum. examples 2560, speed 5291.07 words/sec, time elapsed 190.82 sec
# epoch 3, iter 1090, avg. loss 75.62, avg. ppl 19.85 cum. examples 2880, speed 5805.64 words/sec, time elapsed 192.22 sec
# epoch 3, iter 1100, avg. loss 85.60, avg. ppl 23.97 cum. examples 3200, speed 5324.28 words/sec, time elapsed 193.84 sec
# epoch 3, iter 1110, avg. loss 83.24, avg. ppl 23.19 cum. examples 3520, speed 4408.50 words/sec, time elapsed 195.76 sec
# epoch 3, iter 1120, avg. loss 83.06, avg. ppl 24.73 cum. examples 3840, speed 5252.07 words/sec, time elapsed 197.34 sec
# epoch 3, iter 1130, avg. loss 74.37, avg. ppl 18.71 cum. examples 4160, speed 5260.44 words/sec, time elapsed 198.88 sec
# epoch 3, iter 1140, avg. loss 79.74, avg. ppl 21.54 cum. examples 4480, speed 5449.60 words/sec, time elapsed 200.41 sec
# epoch 3, iter 1150, avg. loss 83.94, avg. ppl 22.49 cum. examples 4800, speed 5650.37 words/sec, time elapsed 201.93 sec
# epoch 3, iter 1160, avg. loss 82.01, avg. ppl 20.99 cum. examples 5120, speed 5601.81 words/sec, time elapsed 203.47 sec
# epoch 3, iter 1170, avg. loss 76.70, avg. ppl 20.69 cum. examples 5440, speed 5506.64 words/sec, time elapsed 204.94 sec
# epoch 3, iter 1180, avg. loss 80.62, avg. ppl 21.66 cum. examples 5760, speed 5429.72 words/sec, time elapsed 206.49 sec
# epoch 3, iter 1190, avg. loss 80.01, avg. ppl 22.50 cum. examples 6080, speed 5856.19 words/sec, time elapsed 207.89 sec
# epoch 3, iter 1200, avg. loss 75.74, avg. ppl 20.28 cum. examples 6400, speed 5796.94 words/sec, time elapsed 209.28 sec
# epoch 3, iter 1200, cum. loss 80.69, cum. ppl 22.03 cum. examples 6400
# begin validation ...
# validation: iter 1200, dev. ppl 44.360106
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 3, iter 1210, avg. loss 75.85, avg. ppl 20.57 cum. examples 320, speed 1195.17 words/sec, time elapsed 216.00 sec
# epoch 3, iter 1220, avg. loss 78.68, avg. ppl 21.03 cum. examples 640, speed 5978.66 words/sec, time elapsed 217.38 sec
# epoch 3, iter 1230, avg. loss 83.72, avg. ppl 23.08 cum. examples 960, speed 5543.87 words/sec, time elapsed 218.92 sec
# epoch 3, iter 1240, avg. loss 81.48, avg. ppl 22.43 cum. examples 1280, speed 5689.88 words/sec, time elapsed 220.39 sec
# epoch 3, iter 1250, avg. loss 78.75, avg. ppl 17.60 cum. examples 1600, speed 5638.50 words/sec, time elapsed 221.95 sec
# epoch 3, iter 1260, avg. loss 82.25, avg. ppl 22.09 cum. examples 1920, speed 5375.73 words/sec, time elapsed 223.53 sec
# epoch 3, iter 1270, avg. loss 86.08, avg. ppl 23.03 cum. examples 2240, speed 4803.19 words/sec, time elapsed 225.36 sec
# epoch 3, iter 1280, avg. loss 75.62, avg. ppl 18.88 cum. examples 2560, speed 5467.73 words/sec, time elapsed 226.87 sec
# epoch 3, iter 1290, avg. loss 75.62, avg. ppl 20.45 cum. examples 2880, speed 5521.51 words/sec, time elapsed 228.32 sec
# epoch 3, iter 1300, avg. loss 73.86, avg. ppl 20.15 cum. examples 3200, speed 5196.58 words/sec, time elapsed 229.84 sec
# epoch 3, iter 1310, avg. loss 84.77, avg. ppl 22.82 cum. examples 3520, speed 5397.69 words/sec, time elapsed 231.44 sec
# epoch 3, iter 1320, avg. loss 80.40, avg. ppl 21.67 cum. examples 3840, speed 5291.61 words/sec, time elapsed 233.02 sec
# epoch 3, iter 1330, avg. loss 77.17, avg. ppl 20.40 cum. examples 4160, speed 5662.98 words/sec, time elapsed 234.47 sec
# epoch 3, iter 1340, avg. loss 80.44, avg. ppl 21.98 cum. examples 4480, speed 5339.13 words/sec, time elapsed 236.03 sec
# epoch 3, iter 1350, avg. loss 78.53, avg. ppl 20.21 cum. examples 4800, speed 5180.74 words/sec, time elapsed 237.64 sec
# epoch 3, iter 1360, avg. loss 81.66, avg. ppl 21.85 cum. examples 5120, speed 5192.51 words/sec, time elapsed 239.28 sec
# epoch 3, iter 1370, avg. loss 72.56, avg. ppl 18.61 cum. examples 5440, speed 5898.86 words/sec, time elapsed 240.62 sec
# epoch 3, iter 1380, avg. loss 84.96, avg. ppl 23.19 cum. examples 5760, speed 4784.07 words/sec, time elapsed 242.43 sec
# epoch 3, iter 1390, avg. loss 79.15, avg. ppl 22.31 cum. examples 6080, speed 5694.21 words/sec, time elapsed 243.86 sec
# epoch 4, iter 1400, avg. loss 72.41, avg. ppl 14.59 cum. examples 6375, speed 5069.91 words/sec, time elapsed 245.43 sec
# epoch 4, iter 1400, cum. loss 79.22, cum. ppl 20.76 cum. examples 6375
# begin validation ...
# validation: iter 1400, dev. ppl 40.393023
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 4, iter 1410, avg. loss 61.21, avg. ppl 11.07 cum. examples 320, speed 1289.82 words/sec, time elapsed 251.75 sec
# epoch 4, iter 1420, avg. loss 59.57, avg. ppl 10.11 cum. examples 640, speed 5572.68 words/sec, time elapsed 253.23 sec
# epoch 4, iter 1430, avg. loss 67.49, avg. ppl 12.55 cum. examples 960, speed 5119.86 words/sec, time elapsed 254.90 sec
# epoch 4, iter 1440, avg. loss 70.16, avg. ppl 13.03 cum. examples 1280, speed 5258.28 words/sec, time elapsed 256.56 sec
# epoch 4, iter 1450, avg. loss 65.00, avg. ppl 11.93 cum. examples 1600, speed 5182.71 words/sec, time elapsed 258.18 sec
# epoch 4, iter 1460, avg. loss 67.37, avg. ppl 14.74 cum. examples 1920, speed 5334.76 words/sec, time elapsed 259.68 sec
# epoch 4, iter 1470, avg. loss 66.24, avg. ppl 12.45 cum. examples 2240, speed 5569.95 words/sec, time elapsed 261.19 sec
# epoch 4, iter 1480, avg. loss 62.76, avg. ppl 11.50 cum. examples 2560, speed 5238.02 words/sec, time elapsed 262.76 sec
# epoch 4, iter 1490, avg. loss 63.59, avg. ppl 11.99 cum. examples 2880, speed 5384.78 words/sec, time elapsed 264.28 sec
# epoch 4, iter 1500, avg. loss 68.10, avg. ppl 12.88 cum. examples 3200, speed 4892.57 words/sec, time elapsed 266.03 sec
# epoch 4, iter 1510, avg. loss 61.77, avg. ppl 11.57 cum. examples 3520, speed 5230.20 words/sec, time elapsed 267.57 sec
# epoch 4, iter 1520, avg. loss 67.87, avg. ppl 13.09 cum. examples 3840, speed 5327.24 words/sec, time elapsed 269.15 sec
# epoch 4, iter 1530, avg. loss 64.80, avg. ppl 12.31 cum. examples 4160, speed 5315.88 words/sec, time elapsed 270.71 sec
# epoch 4, iter 1540, avg. loss 66.50, avg. ppl 13.17 cum. examples 4480, speed 5471.28 words/sec, time elapsed 272.22 sec
# epoch 4, iter 1550, avg. loss 68.89, avg. ppl 13.69 cum. examples 4800, speed 4663.77 words/sec, time elapsed 274.02 sec
# epoch 4, iter 1560, avg. loss 59.88, avg. ppl 10.90 cum. examples 5120, speed 5558.66 words/sec, time elapsed 275.47 sec
# epoch 4, iter 1570, avg. loss 65.00, avg. ppl 12.51 cum. examples 5440, speed 5795.88 words/sec, time elapsed 276.89 sec
# epoch 4, iter 1580, avg. loss 62.10, avg. ppl 12.20 cum. examples 5760, speed 5052.10 words/sec, time elapsed 278.46 sec
# epoch 4, iter 1590, avg. loss 64.96, avg. ppl 12.04 cum. examples 6080, speed 5437.49 words/sec, time elapsed 279.99 sec
# epoch 4, iter 1600, avg. loss 65.39, avg. ppl 11.87 cum. examples 6400, speed 5554.99 words/sec, time elapsed 281.52 sec
# epoch 4, iter 1600, cum. loss 64.93, cum. ppl 12.24 cum. examples 6400
# begin validation ...
# validation: iter 1600, dev. ppl 41.308682
# hit patience 1
# hit #1 trial
# load previously best model and decay learning rate to 0.000250
# restore parameters of the optimizers
# epoch 4, iter 1610, avg. loss 67.52, avg. ppl 13.04 cum. examples 320, speed 1835.59 words/sec, time elapsed 286.10 sec
# epoch 4, iter 1620, avg. loss 65.67, avg. ppl 11.54 cum. examples 640, speed 5815.89 words/sec, time elapsed 287.58 sec
# epoch 4, iter 1630, avg. loss 63.82, avg. ppl 11.92 cum. examples 960, speed 5383.65 words/sec, time elapsed 289.11 sec
# epoch 4, iter 1640, avg. loss 61.13, avg. ppl 10.96 cum. examples 1280, speed 5539.34 words/sec, time elapsed 290.58 sec
# epoch 4, iter 1650, avg. loss 63.64, avg. ppl 11.11 cum. examples 1600, speed 5423.96 words/sec, time elapsed 292.14 sec
# epoch 4, iter 1660, avg. loss 62.76, avg. ppl 10.77 cum. examples 1920, speed 5598.84 words/sec, time elapsed 293.65 sec
# epoch 4, iter 1670, avg. loss 63.46, avg. ppl 10.35 cum. examples 2240, speed 5714.86 words/sec, time elapsed 295.17 sec
# epoch 4, iter 1680, avg. loss 68.10, avg. ppl 11.97 cum. examples 2560, speed 5139.29 words/sec, time elapsed 296.88 sec
# epoch 4, iter 1690, avg. loss 61.50, avg. ppl 10.75 cum. examples 2880, speed 5613.48 words/sec, time elapsed 298.36 sec
# epoch 4, iter 1700, avg. loss 62.80, avg. ppl 11.48 cum. examples 3200, speed 5265.08 words/sec, time elapsed 299.92 sec
# epoch 4, iter 1710, avg. loss 63.24, avg. ppl 10.63 cum. examples 3520, speed 5924.11 words/sec, time elapsed 301.37 sec
# epoch 4, iter 1720, avg. loss 61.98, avg. ppl 10.97 cum. examples 3840, speed 5758.16 words/sec, time elapsed 302.81 sec
# epoch 4, iter 1730, avg. loss 61.46, avg. ppl 10.81 cum. examples 4160, speed 5315.85 words/sec, time elapsed 304.36 sec
# epoch 4, iter 1740, avg. loss 61.33, avg. ppl 10.37 cum. examples 4480, speed 5821.05 words/sec, time elapsed 305.80 sec
# epoch 4, iter 1750, avg. loss 58.99, avg. ppl 10.10 cum. examples 4800, speed 5573.64 words/sec, time elapsed 307.27 sec
# epoch 4, iter 1760, avg. loss 66.35, avg. ppl 12.62 cum. examples 5120, speed 5655.87 words/sec, time elapsed 308.75 sec
# epoch 4, iter 1770, avg. loss 61.13, avg. ppl 11.37 cum. examples 5440, speed 5618.92 words/sec, time elapsed 310.18 sec
# epoch 4, iter 1780, avg. loss 62.52, avg. ppl 10.56 cum. examples 5760, speed 5565.07 words/sec, time elapsed 311.70 sec
# epoch 4, iter 1790, avg. loss 63.91, avg. ppl 11.46 cum. examples 6080, speed 5303.52 words/sec, time elapsed 313.29 sec
# epoch 4, iter 1800, avg. loss 63.03, avg. ppl 10.87 cum. examples 6400, speed 5720.74 words/sec, time elapsed 314.76 sec
# epoch 4, iter 1800, cum. loss 63.22, cum. ppl 11.16 cum. examples 6400
# begin validation ...
# validation: iter 1800, dev. ppl 39.213054
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 4, iter 1810, avg. loss 59.17, avg. ppl 9.74 cum. examples 320, speed 1268.96 words/sec, time elapsed 321.32 sec
# epoch 4, iter 1820, avg. loss 61.91, avg. ppl 10.95 cum. examples 640, speed 5427.20 words/sec, time elapsed 322.84 sec
# epoch 4, iter 1830, avg. loss 63.23, avg. ppl 10.55 cum. examples 960, speed 5648.94 words/sec, time elapsed 324.36 sec
# epoch 4, iter 1840, avg. loss 62.39, avg. ppl 10.83 cum. examples 1280, speed 5370.99 words/sec, time elapsed 325.92 sec
# epoch 4, iter 1850, avg. loss 63.94, avg. ppl 11.16 cum. examples 1600, speed 5243.69 words/sec, time elapsed 327.54 sec
# epoch 4, iter 1860, avg. loss 64.03, avg. ppl 11.07 cum. examples 1895, speed 5352.87 words/sec, time elapsed 329.01 sec
# epoch 5, iter 1870, avg. loss 59.00, avg. ppl 8.97 cum. examples 2215, speed 5515.88 words/sec, time elapsed 330.57 sec
# epoch 5, iter 1880, avg. loss 54.51, avg. ppl 8.04 cum. examples 2535, speed 5455.70 words/sec, time elapsed 332.10 sec
# epoch 5, iter 1890, avg. loss 55.18, avg. ppl 8.00 cum. examples 2855, speed 5356.87 words/sec, time elapsed 333.69 sec
# epoch 5, iter 1900, avg. loss 55.30, avg. ppl 8.08 cum. examples 3175, speed 5892.72 words/sec, time elapsed 335.13 sec
# epoch 5, iter 1910, avg. loss 53.01, avg. ppl 8.00 cum. examples 3495, speed 5510.14 words/sec, time elapsed 336.61 sec
# epoch 5, iter 1920, avg. loss 60.24, avg. ppl 9.46 cum. examples 3815, speed 5056.70 words/sec, time elapsed 338.30 sec
# epoch 5, iter 1930, avg. loss 51.43, avg. ppl 7.70 cum. examples 4135, speed 5846.16 words/sec, time elapsed 339.68 sec
# epoch 5, iter 1940, avg. loss 55.36, avg. ppl 8.39 cum. examples 4455, speed 4852.24 words/sec, time elapsed 341.40 sec
# epoch 5, iter 1950, avg. loss 57.39, avg. ppl 8.51 cum. examples 4775, speed 5946.68 words/sec, time elapsed 342.84 sec
# epoch 5, iter 1960, avg. loss 55.03, avg. ppl 8.31 cum. examples 5095, speed 5437.79 words/sec, time elapsed 344.37 sec
# epoch 5, iter 1970, avg. loss 58.30, avg. ppl 8.45 cum. examples 5415, speed 6095.90 words/sec, time elapsed 345.80 sec
# epoch 5, iter 1980, avg. loss 56.15, avg. ppl 8.92 cum. examples 5735, speed 5198.88 words/sec, time elapsed 347.38 sec
# epoch 5, iter 1990, avg. loss 59.58, avg. ppl 9.20 cum. examples 6055, speed 5268.58 words/sec, time elapsed 349.01 sec
# epoch 5, iter 2000, avg. loss 56.02, avg. ppl 8.64 cum. examples 6375, speed 5411.78 words/sec, time elapsed 350.55 sec
# epoch 5, iter 2000, cum. loss 58.03, cum. ppl 9.08 cum. examples 6375
# begin validation ...
# validation: iter 2000, dev. ppl 40.380767
# hit patience 1
# hit #2 trial
# load previously best model and decay learning rate to 0.000125
# restore parameters of the optimizers
# epoch 5, iter 2010, avg. loss 53.51, avg. ppl 8.59 cum. examples 320, speed 2076.91 words/sec, time elapsed 354.38 sec
# epoch 5, iter 2020, avg. loss 62.01, avg. ppl 10.70 cum. examples 640, speed 4623.53 words/sec, time elapsed 356.20 sec
# epoch 5, iter 2030, avg. loss 58.36, avg. ppl 9.65 cum. examples 960, speed 4813.69 words/sec, time elapsed 357.91 sec
# epoch 5, iter 2040, avg. loss 57.30, avg. ppl 9.18 cum. examples 1280, speed 5506.85 words/sec, time elapsed 359.41 sec
# epoch 5, iter 2050, avg. loss 53.91, avg. ppl 8.11 cum. examples 1600, speed 5880.38 words/sec, time elapsed 360.81 sec
# epoch 5, iter 2060, avg. loss 55.32, avg. ppl 8.55 cum. examples 1920, speed 5736.62 words/sec, time elapsed 362.25 sec
# epoch 5, iter 2070, avg. loss 53.60, avg. ppl 8.36 cum. examples 2240, speed 5465.34 words/sec, time elapsed 363.73 sec
# epoch 5, iter 2080, avg. loss 56.94, avg. ppl 8.90 cum. examples 2560, speed 5529.50 words/sec, time elapsed 365.23 sec
# epoch 5, iter 2090, avg. loss 57.63, avg. ppl 8.66 cum. examples 2880, speed 5701.02 words/sec, time elapsed 366.73 sec
# epoch 5, iter 2100, avg. loss 55.90, avg. ppl 8.51 cum. examples 3200, speed 5341.04 words/sec, time elapsed 368.30 sec
# epoch 5, iter 2110, avg. loss 56.85, avg. ppl 8.58 cum. examples 3520, speed 5656.82 words/sec, time elapsed 369.79 sec
# epoch 5, iter 2120, avg. loss 57.31, avg. ppl 9.48 cum. examples 3840, speed 5005.77 words/sec, time elapsed 371.42 sec
# epoch 5, iter 2130, avg. loss 55.93, avg. ppl 9.21 cum. examples 4160, speed 5389.71 words/sec, time elapsed 372.92 sec
# epoch 5, iter 2140, avg. loss 55.63, avg. ppl 8.98 cum. examples 4480, speed 4934.56 words/sec, time elapsed 374.56 sec
# epoch 5, iter 2150, avg. loss 54.66, avg. ppl 7.99 cum. examples 4800, speed 5748.04 words/sec, time elapsed 376.02 sec
# epoch 5, iter 2160, avg. loss 55.08, avg. ppl 8.33 cum. examples 5120, speed 5351.34 words/sec, time elapsed 377.58 sec
# epoch 5, iter 2170, avg. loss 61.63, avg. ppl 9.41 cum. examples 5440, speed 4159.13 words/sec, time elapsed 379.69 sec
# epoch 5, iter 2180, avg. loss 54.33, avg. ppl 7.77 cum. examples 5760, speed 5653.63 words/sec, time elapsed 381.19 sec
# epoch 5, iter 2190, avg. loss 56.04, avg. ppl 8.60 cum. examples 6080, speed 5283.39 words/sec, time elapsed 382.77 sec
# epoch 5, iter 2200, avg. loss 62.68, avg. ppl 9.86 cum. examples 6400, speed 5570.50 words/sec, time elapsed 384.34 sec
# epoch 5, iter 2200, cum. loss 56.73, cum. ppl 8.85 cum. examples 6400
# begin validation ...
# validation: iter 2200, dev. ppl 39.462719
# hit patience 1
# hit #3 trial
# load previously best model and decay learning rate to 0.000063
# restore parameters of the optimizers
# epoch 5, iter 2210, avg. loss 57.35, avg. ppl 9.34 cum. examples 320, speed 2114.13 words/sec, time elapsed 388.23 sec
# epoch 5, iter 2220, avg. loss 59.82, avg. ppl 9.75 cum. examples 640, speed 5537.70 words/sec, time elapsed 389.75 sec
# epoch 5, iter 2230, avg. loss 53.30, avg. ppl 8.05 cum. examples 960, speed 5546.49 words/sec, time elapsed 391.22 sec
# epoch 5, iter 2240, avg. loss 55.75, avg. ppl 8.51 cum. examples 1280, speed 6070.06 words/sec, time elapsed 392.59 sec
# epoch 5, iter 2250, avg. loss 57.11, avg. ppl 8.68 cum. examples 1600, speed 5636.43 words/sec, time elapsed 394.09 sec
# epoch 5, iter 2260, avg. loss 56.33, avg. ppl 9.20 cum. examples 1920, speed 5345.21 words/sec, time elapsed 395.61 sec
# epoch 5, iter 2270, avg. loss 57.48, avg. ppl 8.65 cum. examples 2240, speed 5593.05 words/sec, time elapsed 397.14 sec
# epoch 5, iter 2280, avg. loss 58.69, avg. ppl 8.71 cum. examples 2560, speed 5811.65 words/sec, time elapsed 398.63 sec
# epoch 5, iter 2290, avg. loss 57.25, avg. ppl 8.50 cum. examples 2880, speed 5684.78 words/sec, time elapsed 400.14 sec
# epoch 5, iter 2300, avg. loss 58.21, avg. ppl 9.09 cum. examples 3200, speed 5483.75 words/sec, time elapsed 401.68 sec
# epoch 5, iter 2310, avg. loss 55.53, avg. ppl 8.55 cum. examples 3520, speed 5646.22 words/sec, time elapsed 403.14 sec
# epoch 5, iter 2320, avg. loss 52.67, avg. ppl 8.11 cum. examples 3840, speed 5584.33 words/sec, time elapsed 404.58 sec
# epoch 6, iter 2330, avg. loss 53.63, avg. ppl 8.51 cum. examples 4135, speed 5381.08 words/sec, time elapsed 405.96 sec
# epoch 6, iter 2340, avg. loss 53.70, avg. ppl 8.29 cum. examples 4455, speed 5519.13 words/sec, time elapsed 407.43 sec
# epoch 6, iter 2350, avg. loss 58.12, avg. ppl 8.64 cum. examples 4775, speed 5327.64 words/sec, time elapsed 409.05 sec
# epoch 6, iter 2360, avg. loss 55.26, avg. ppl 8.48 cum. examples 5095, speed 5100.38 words/sec, time elapsed 410.67 sec
# epoch 6, iter 2370, avg. loss 50.91, avg. ppl 7.90 cum. examples 5415, speed 5766.50 words/sec, time elapsed 412.04 sec
# epoch 6, iter 2380, avg. loss 50.41, avg. ppl 7.41 cum. examples 5735, speed 5917.18 words/sec, time elapsed 413.40 sec
# epoch 6, iter 2390, avg. loss 51.22, avg. ppl 7.63 cum. examples 6055, speed 5342.91 words/sec, time elapsed 414.91 sec
# epoch 6, iter 2400, avg. loss 56.53, avg. ppl 8.06 cum. examples 6375, speed 5550.75 words/sec, time elapsed 416.47 sec
# epoch 6, iter 2400, cum. loss 55.47, cum. ppl 8.49 cum. examples 6375
# begin validation ...
# validation: iter 2400, dev. ppl 39.464994
# hit patience 1
# hit #4 trial
# load previously best model and decay learning rate to 0.000031
# restore parameters of the optimizers
# epoch 6, iter 2410, avg. loss 58.21, avg. ppl 8.53 cum. examples 320, speed 2283.69 words/sec, time elapsed 420.27 sec
# epoch 6, iter 2420, avg. loss 55.48, avg. ppl 8.61 cum. examples 640, speed 5424.35 words/sec, time elapsed 421.79 sec
# epoch 6, iter 2430, avg. loss 58.00, avg. ppl 9.06 cum. examples 960, speed 5759.65 words/sec, time elapsed 423.26 sec
# epoch 6, iter 2440, avg. loss 58.32, avg. ppl 9.22 cum. examples 1280, speed 5929.35 words/sec, time elapsed 424.67 sec
# epoch 6, iter 2450, avg. loss 58.61, avg. ppl 8.98 cum. examples 1600, speed 5256.23 words/sec, time elapsed 426.30 sec
# epoch 6, iter 2460, avg. loss 56.30, avg. ppl 8.27 cum. examples 1920, speed 5769.97 words/sec, time elapsed 427.78 sec
# epoch 6, iter 2470, avg. loss 57.38, avg. ppl 8.63 cum. examples 2240, speed 6139.41 words/sec, time elapsed 429.17 sec
# epoch 6, iter 2480, avg. loss 54.63, avg. ppl 8.51 cum. examples 2560, speed 5783.70 words/sec, time elapsed 430.58 sec
# epoch 6, iter 2490, avg. loss 59.69, avg. ppl 9.47 cum. examples 2880, speed 5368.31 words/sec, time elapsed 432.16 sec
# epoch 6, iter 2500, avg. loss 63.90, avg. ppl 9.15 cum. examples 3200, speed 5512.60 words/sec, time elapsed 433.84 sec
# epoch 6, iter 2510, avg. loss 57.39, avg. ppl 8.96 cum. examples 3520, speed 5603.45 words/sec, time elapsed 435.33 sec
# epoch 6, iter 2520, avg. loss 54.59, avg. ppl 8.16 cum. examples 3840, speed 5619.96 words/sec, time elapsed 436.81 sec
# epoch 6, iter 2530, avg. loss 59.11, avg. ppl 9.15 cum. examples 4160, speed 5124.35 words/sec, time elapsed 438.48 sec
# epoch 6, iter 2540, avg. loss 59.06, avg. ppl 8.72 cum. examples 4480, speed 5536.69 words/sec, time elapsed 440.06 sec
# epoch 6, iter 2550, avg. loss 58.64, avg. ppl 9.47 cum. examples 4800, speed 5204.48 words/sec, time elapsed 441.66 sec
# epoch 6, iter 2560, avg. loss 51.50, avg. ppl 8.09 cum. examples 5120, speed 5153.06 words/sec, time elapsed 443.19 sec
# epoch 6, iter 2570, avg. loss 61.50, avg. ppl 9.55 cum. examples 5440, speed 5172.97 words/sec, time elapsed 444.88 sec
# epoch 6, iter 2580, avg. loss 59.20, avg. ppl 9.22 cum. examples 5760, speed 4772.42 words/sec, time elapsed 446.66 sec
# epoch 6, iter 2590, avg. loss 58.23, avg. ppl 9.46 cum. examples 6080, speed 5480.95 words/sec, time elapsed 448.18 sec
# epoch 6, iter 2600, avg. loss 60.93, avg. ppl 9.27 cum. examples 6400, speed 5161.33 words/sec, time elapsed 449.87 sec
# epoch 6, iter 2600, cum. loss 58.03, cum. ppl 8.92 cum. examples 6400
# begin validation ...
# validation: iter 2600, dev. ppl 38.963645
# save currently the best model to [model.bin]
# save model parameters to [model.bin]
# epoch 6, iter 2610, avg. loss 55.85, avg. ppl 8.28 cum. examples 320, speed 1227.41 words/sec, time elapsed 456.76 sec
# epoch 6, iter 2620, avg. loss 55.81, avg. ppl 9.15 cum. examples 640, speed 5825.75 words/sec, time elapsed 458.15 sec
# epoch 6, iter 2630, avg. loss 54.50, avg. ppl 8.50 cum. examples 960, speed 5434.72 words/sec, time elapsed 459.65 sec
# epoch 6, iter 2640, avg. loss 54.04, avg. ppl 8.61 cum. examples 1280, speed 5376.82 words/sec, time elapsed 461.14 sec
# epoch 6, iter 2650, avg. loss 58.25, avg. ppl 8.73 cum. examples 1600, speed 5458.93 words/sec, time elapsed 462.72 sec
# epoch 6, iter 2660, avg. loss 53.74, avg. ppl 8.20 cum. examples 1920, speed 5393.17 words/sec, time elapsed 464.23 sec
# epoch 6, iter 2670, avg. loss 54.97, avg. ppl 8.04 cum. examples 2240, speed 5733.22 words/sec, time elapsed 465.70 sec
# epoch 6, iter 2680, avg. loss 54.22, avg. ppl 8.51 cum. examples 2560, speed 5120.71 words/sec, time elapsed 467.29 sec
# epoch 6, iter 2690, avg. loss 56.68, avg. ppl 9.16 cum. examples 2880, speed 5106.90 words/sec, time elapsed 468.89 sec
# epoch 6, iter 2700, avg. loss 51.82, avg. ppl 8.03 cum. examples 3200, speed 5523.84 words/sec, time elapsed 470.33 sec
# epoch 6, iter 2710, avg. loss 53.31, avg. ppl 7.84 cum. examples 3520, speed 5317.84 words/sec, time elapsed 471.89 sec
# epoch 6, iter 2720, avg. loss 52.40, avg. ppl 8.49 cum. examples 3840, speed 5159.23 words/sec, time elapsed 473.41 sec
# epoch 6, iter 2730, avg. loss 54.09, avg. ppl 8.21 cum. examples 4160, speed 5498.72 words/sec, time elapsed 474.90 sec
# epoch 6, iter 2740, avg. loss 56.27, avg. ppl 8.87 cum. examples 4480, speed 5580.94 words/sec, time elapsed 476.38 sec
# epoch 6, iter 2750, avg. loss 59.04, avg. ppl 9.23 cum. examples 4800, speed 4892.85 words/sec, time elapsed 478.12 sec
# epoch 6, iter 2760, avg. loss 54.52, avg. ppl 8.55 cum. examples 5120, speed 5797.07 words/sec, time elapsed 479.52 sec
# epoch 6, iter 2770, avg. loss 58.96, avg. ppl 8.90 cum. examples 5440, speed 5670.34 words/sec, time elapsed 481.04 sec
# epoch 6, iter 2780, avg. loss 57.26, avg. ppl 8.44 cum. examples 5760, speed 4982.54 words/sec, time elapsed 482.77 sec
# epoch 6, iter 2790, avg. loss 57.04, avg. ppl 8.44 cum. examples 6055, speed 5263.11 words/sec, time elapsed 484.27 sec
# epoch 7, iter 2800, avg. loss 53.64, avg. ppl 7.83 cum. examples 6375, speed 5467.74 words/sec, time elapsed 485.79 sec
# epoch 7, iter 2800, cum. loss 55.31, cum. ppl 8.49 cum. examples 6375
# begin validation ...
# validation: iter 2800, dev. ppl 39.123033
# hit patience 1
# hit #5 trial
# early stop!

# %%
# !sh run.sh test
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# load test source sentences from [./chr_en_data/test.chr]
# load test target sentences from [./chr_en_data/test.en]
# load model from model.bin
# Decoding:   0% 0/1000 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# Decoding: 100% 1000/1000 [00:44<00:00, 22.44it/s]
# Corpus BLEU: 12.278101290066378

# %%
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
